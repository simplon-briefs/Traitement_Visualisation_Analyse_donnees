# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Data_Vis/tendance_centrale.csv")
df.mean()
df.median()
df.mode()
# Out:
#      Nom   Age  Rating
# 0  perez  53.0    3.78
# 1    NaN   NaN    3.95
# 2    NaN   NaN    4.30
# 3    NaN   NaN    4.80
# 4    NaN   NaN    5.98

# %%
plt.scatter(df["Age"], df["Rating"])

# %%
df = pd.read_csv("Data_Vis/iris.csv")
df.head()
# Out:
#    longueur_sepal  largeur_sepal  longueur_petal  largeur_petal  espèce
# 0             5.1            3.5             1.4            0.2  setosa
# 1             4.9            3.0             1.4            0.2  setosa
# 2             4.7            3.2             1.3            0.2  setosa
# 3             4.6            3.1             1.5            0.2  setosa
# 4             5.0            3.6             1.4            0.2  setosa

# %%
df_corr = df.corr()

# %%
plt.scatter(df_corr["longueur_sepal"], df_corr["largeur_sepal"])
